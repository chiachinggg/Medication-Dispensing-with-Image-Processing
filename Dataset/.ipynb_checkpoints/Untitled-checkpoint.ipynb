# %%
pip install tensorflow
# Out:
# ...
#
# ...

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import pytesseract

# %%
df = pd.read_csv("med_data.csv")

# Get a specific column by column name
column_data = df["id"]

# %%
df
# Out:
#              brand_name generic_name    strength form_name form_abbr  \
# 0     Codeine Phosphate          NaN        30mg    Tablet       Tab
# 1               Senokot          NaN         NaN    Tablet       Tab
# 2              Prunelax          NaN         NaN    Tablet       Tab
# 3              Dulcolax          NaN         NaN    Tablet       Tab
# 4                 Favic          NaN         NaN    Tablet       Tab
# ...                 ...          ...         ...       ...       ...
# 1520            STILNOX     Zolpidem  6.25mg, CR    Tablet       Tab
# 1521            STILNOX     Zolpidem  12.5mg, CR    Tablet       Tab
# 1522            IMOVANE    Zopiclone       7.5mg    Tablet       Tab
# 1523            IMOVANE    Zopiclone       7.5mg    Tablet       Tab
# 1524             IMREST    Zopiclone       7.5mg    Tablet       Tab
#
#      pack_size brand schedule    id
# 0           20  (FM)        8     1
# 1            1   NaN       NS     2
# ...

# %%
array=[]
array2=[]
array3=[]
# Iterate over each row
for index, row in df.iterrows():
    # Access data from each column in the current row
    brand_name = row['brand_name']
    generic_name = row['generic_name']
    strength = row['strength']
    id = row['id']
#     med = str(brand_name) + str(generic_name) + str(strength)
    med = (brand_name, generic_name, strength)
    if med not in array:
        array.append(med)
        array2.append(str(id))
        array3.append(False)
    elif med in array:
        print(med, str(id))
        for i in range(len(array)):
            if array[i] == med and array3[i] == False:
                print(array[i], array2[i])
                array3[i] = True
        
print(len(array))
# Out:
# ('Viclofen', nan, nan) 17
# ('Viclofen', nan, nan) 16
# ('Aspro clear', nan, nan) 19
# ('Aspro clear', nan, nan) 18
# ('Aspro clear', nan, nan) 20
# ('Cartia', nan, nan) 23
# ('Cartia', nan, nan) 22
# ('Cartia', nan, nan) 24
# ('Maxigesic', nan, nan) 28
# ('Maxigesic', nan, nan) 27
# ('Panadol with Optizorb', nan, nan) 32
# ('Panadol with Optizorb', nan, nan) 7
# ('Panadol', nan, nan) 34
# ('Panadol', nan, nan) 33
# ('Nurofen', nan, nan) 38
# ('Nurofen', nan, nan) 37
# ('Nurofen', nan, nan) 39
# ('Voltaren rapid 25', nan, nan) 42
# ('Voltaren rapid 25', nan, nan) 41
# ('Lacteeze', nan, nan) 57
# ('Lacteeze', nan, nan) 56
# ('Nozoil 15ml', nan, nan) 232
# ('Nozoil 15ml', nan, nan) 187
# ('Prospan 200ml', nan, nan) 263
# ('Prospan 200ml', nan, nan) 258
# ('Nurofen', nan, nan) 313
# ('DIFFERIN', 'Adapalene', '0.1%, 30g') 328
# ('DIFFERIN', 'Adapalene', '0.1%, 30g') 327
# ('ZITHROMAX', 'Azithromycin', '500mg') 420
# ('ZITHROMAX', 'Azithromycin', '500mg') 419
# ...

# %%
from PIL import Image
import os

# %%
# Folder containing PNG images
folder_path = "C:/Users/jieru/Downloads/mydispense_meds"

# %%
# List all files in the folder
files = os.listdir(folder_path)

# %%
# Iterate over each file
count = 0
for file in files:
    if file.endswith(".png"):
        count += 1
        # Construct the full path to the image
        image_path = os.path.join(folder_path, file)
        
        # Open the PNG image
        image = Image.open(image_path)
        
        # Display basic information about the image
        print("Image:", file)
        if
print(count)
        
#         print("Image format:", image.format)
#         print("Image mode:", image.mode)
#         print("Image size:", image.size)
        
        # Show the image (optional)
        # image.show()
        
        # Convert the image to a numpy array (if needed)
        # import numpy as np
        # image_array = np.array(image)
# Out:
# Image: 1.png
# Image: 10.png
# Image: 100.png
# Image: 1000.png
# Image: 1001.png
# Image: 1002.png
# Image: 1003.png
# Image: 1004.png
# Image: 1005.png
# Image: 1006.png
# Image: 1007.png
# Image: 1008.png
# Image: 1009.png
# Image: 101.png
# Image: 1010.png
# Image: 1011.png
# Image: 1012.png
# Image: 1013.png
# Image: 1014.png
# Image: 1015.png
# Image: 1016.png
# Image: 1017.png
# Image: 1018.png
# Image: 1019.png
# Image: 102.png
# Image: 1020.png
# Image: 1021.png
# Image: 1022.png
# Image: 1023.png
# Image: 1024.png
# Image: 1025.png
# Image: 1026.png
# Image: 1027.png
# Image: 1028.png
# Image: 1029.png
# Image: 103.png
# Image: 1030.png
# Image: 1031.png
# Image: 1032.png
# Image: 1033.png
# Image: 1034.png
# Image: 1035.png
# Image: 1036.png
# Image: 1037.png
# Image: 1038.png
# Image: 1039.png
# Image: 104.png
# Image: 1040.png
# Image: 1041.png
# Image: 1042.png
# Image: 1043.png
# Image: 1044.png
# Image: 1045.png
# Image: 1046.png
# Image: 1047.png
# Image: 1048.png
# ...
